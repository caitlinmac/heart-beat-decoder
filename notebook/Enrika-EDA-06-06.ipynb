# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_raw = pd.read_csv('/Users/enrikasoucy/Downloads/archive (13)/INCART 2-lead Arrhythmia Database.csv')

# %%
data_raw
# Out:
#        record type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak  \
# 0         I01    N       163        165  0.069610 -0.083281  0.614133
# 1         I01    N       165        166 -0.097030  0.597254 -0.078704
# 2         I01    N       166        102  0.109399  0.680528 -0.010649
# 3         I01  VEB       102        231  0.176376  0.256431 -0.101098
# 4         I01    N       231        165  0.585577  0.607461 -0.083499
# ...       ...  ...       ...        ...       ...       ...       ...
# 175724    I75  VEB       205        254  0.167375  0.998450 -1.884460
# 175725    I75    N       254        231  0.067664  0.986674 -0.321804
# 175726    I75    N       231        229 -0.129754  0.746366 -0.303551
# 175727    I75    N       229        232 -0.133953  0.747789 -0.626746
# 175728    I75    N       232        213 -0.157739  0.835266 -0.197554
#
#          0_sPeak   0_qPeak  0_qrs_interval  ...   1_qPeak  1_qrs_interval  \
# ...
